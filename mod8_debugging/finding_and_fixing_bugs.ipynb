# %% [markdown]
# # Debugging: Finding and Fixing Bugs

# %%
from TicTacToe import TicTacToe
game = TicTacToe()
# Out:
# Welcome to Tic Tac Toe!
# User input should be one of the moves below:
# top_left, top_center, top_right, middle_left, middle_center, middle_right, bottom_left, bottom_center, bottom_right

# %%
game.play_game()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 game.play_game()
#
# File ~/Downloads/bwsi-intro-python/mod8_debugging/TicTacToe.py:78, in TicTacToe.play_game(self)
#      76 end_game = False
#      77 while not end_game:
# ---> 78     self.__user_take_turn()
#      79     end_game, message = self.__check_end_conditions("USER")
#      80     if end_game:
#
# File ~/Downloads/bwsi-intro-python/mod8_debugging/TicTacToe.py:57, in TicTacToe.__user_take_turn(self)
#      55 def __user_take_turn(self):
#      56     """Prompt the user to take their turn."""
# ---> 57     user_move = input("Please take your turn: ")
#      58     if MoveType[user_move].value in self.valid_moves:
#      59         move_index = MoveType[user_move].value
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
# ...
